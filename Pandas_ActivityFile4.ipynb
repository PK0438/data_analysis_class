# %% [markdown]
# ## **Pandas - Series Object**

# %%
import numpy as np
import pandas as pd

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
pd.Series([10, 20, 30, 40, 50])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.Series([10, 20, 30, 40, 50], dtype='float')
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4    50.0
# dtype: float64

# %%
ice_creams = pd.Series(['Vanilla', 'Chocolate', 'Strawberry'])
ice_creams
# Out:
# 0       Vanilla
# 1     Chocolate
# 2    Strawberry
# dtype: object
