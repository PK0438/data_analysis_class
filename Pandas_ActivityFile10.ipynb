# %% [markdown]
# ## **Multi Index DataFrame**

# %%
import numpy as np
import pandas as pd

# %%
columns = ["Morning", "Evening"]
rows = ["Mon", "Tue", "Wed"]

data = [
    (1, 2),
    (3, 4),
    (5, 6)
]

pd.DataFrame(data=data, index=rows, columns=columns)
# Out:
#      Morning  Evening
# Mon        1        2
# Tue        3        4
# Wed        5        6

# %%
columns_index = pd.MultiIndex.from_tuples([
    ("Services", "Schools"),
    ("Services", "Police"),
    ("Culture", "Museum"),
    ("Culture", "Restuarants")
])

row_index = pd.MultiIndex.from_tuples([
    ("Malkajgiri", "TS", "500047"),
    ("Marredpally", "TS", "500026"),
    ("Musheerabad", "TS", "500020")
])
row_index.names = ["Street", "City", "Zip"]

data = [
    ["A", "B", "A+", "C"],
    ["B+", "C", "C+", "A"],
    ["A", "A", "C", "C"]
]

pd.DataFrame(data=data, index=row_index, columns=columns_index)
# Out:
#                         Services        Culture
#                          Schools Police  Museum Restuarants
# Street      City Zip
# Malkajgiri  TS   500047        A      B      A+           C
# Marredpally TS   500026       B+      C      C+           A
# Musheerabad TS   500020        A      A       C           C

# %%
neighborhoods = pd.read_csv("data/neighborhoods.csv")
neighborhoods
# Out:
#     Unnamed: 0          Unnamed: 1         Unnamed: 2      Culture Culture.1  \
# 0          NaN                 NaN                NaN  Restaurants   Museums
# 1        State                City             Street          NaN       NaN
# 2           MO       Fisherborough     244 Tracy View           C+         F
# 3           SD    Port Curtisville  446 Cynthia Inlet           C-         B
# 4           WV         Jimenezview    432 John Common            A        A+
# ..         ...                 ...                ...          ...       ...
# 248         MI       North Matthew   055 Clayton Isle           B-         C
# 249         MT             Chadton  601 Richards Road           A-         D
# 250         SC           Diazmouth  385 Robin Harbors            F         D
# 251         VA          Laurentown  255 Gonzalez Land           C+        B-
# 252         NE  South Kennethmouth   346 Wallace Pass           C-        B-
#
#     Services Services.1
# 0     Police    Schools
# 1        NaN        NaN
# 2         D-         A+
# 3          B         D+
# 4          F          B
# ..       ...        ...
# 248        B         C+
# 249       D+          D
# 250       B-         D+
# 251        F         D-
# 252        A         A-
#
# [253 rows x 7 columns]

# %%
# fix the issues
#

neighborhoods = pd.read_csv("data/neighborhoods.csv",
                            index_col=[0, 1, 2],
                            header=[0, 1])
neighborhoods
# Out:
#                                                Culture         Services  \
#                                            Restaurants Museums   Police
# State City               Street
# MO    Fisherborough      244 Tracy View             C+       F       D-
# SD    Port Curtisville   446 Cynthia Inlet          C-       B        B
# WV    Jimenezview        432 John Common             A      A+        F
# AK    Stevenshire        238 Andrew Rue             D-       A       A-
# ND    New Joshuaport     877 Walter Neck            D+      C-        B
# ...                                                ...     ...      ...
# MI    North Matthew      055 Clayton Isle           B-       C        B
# MT    Chadton            601 Richards Road          A-       D       D+
# SC    Diazmouth          385 Robin Harbors           F       D       B-
# VA    Laurentown         255 Gonzalez Land          C+      B-        F
# NE    South Kennethmouth 346 Wallace Pass           C-      B-        A
#
#
#                                            Schools
# State City               Street
# MO    Fisherborough      244 Tracy View         A+
# SD    Port Curtisville   446 Cynthia Inlet      D+
# WV    Jimenezview        432 John Common         B
# AK    Stevenshire        238 Andrew Rue         A-
# ND    New Joshuaport     877 Walter Neck         B
# ...                                            ...
# MI    North Matthew      055 Clayton Isle       C+
# MT    Chadton            601 Richards Road       D
# SC    Diazmouth          385 Robin Harbors      D+
# VA    Laurentown         255 Gonzalez Land      D-
# NE    South Kennethmouth 346 Wallace Pass       A-
#
# [251 rows x 4 columns]

# %%
neighborhoods.index
# Out:
# MultiIndex([('MO',      'Fisherborough',        '244 Tracy View'),
#             ('SD',   'Port Curtisville',     '446 Cynthia Inlet'),
#             ('WV',        'Jimenezview',       '432 John Common'),
#             ('AK',        'Stevenshire',        '238 Andrew Rue'),
#             ('ND',     'New Joshuaport',       '877 Walter Neck'),
#             ('ID',         'Wellsville',   '696 Weber Stravenue'),
#             ('TN',          'Jodiburgh',    '285 Justin Corners'),
#             ('DC',   'Lake Christopher',   '607 Montoya Harbors'),
#             ('OH',          'Port Mike',      '041 Michael Neck'),
#             ('ND',         'Hardyburgh', '550 Gilmore Mountains'),
#             ...
#             ('AK',          'Scottstad',      '114 Jones Garden'),
#             ('IA',    'Port Willieport',  '320 Jennifer Mission'),
#             ('ME',         'Port Linda',        '692 Hill Glens'),
#             ('KS',         'Kaylamouth',       '483 Freeman Via'),
#             ('WA',     'Port Shawnfort',    '691 Winters Bridge'),
#             ('MI',      'North Matthew',      '055 Clayton Isle'),
#             ('MT',            'Chadton',     '601 Richards Road'),
#             ('SC',          'Diazmouth',     '385 Robin Harbors'),
#             ('VA',         'Laurentown',     '255 Gonzalez Land'),
#             ('NE', 'South Kennethmouth',      '346 Wallace Pass')],
#            names=['State', 'City', 'Street'], length=251)

# %%
neighborhoods.index.names
# Out:
# FrozenList(['State', 'City', 'Street'])

# %%
neighborhoods.columns
# Out:
# MultiIndex([( 'Culture', 'Restaurants'),
#             ( 'Culture',     'Museums'),
#             ('Services',      'Police'),
#             ('Services',     'Schools')],
#            )

# %%
neighborhoods.columns.names
# Out:
# FrozenList([None, None])

# %%
neighborhoods.columns.names = ['Category', 'Subcategory']
neighborhoods
# Out:
# Category                                       Culture         Services  \
# Subcategory                                Restaurants Museums   Police
# State City               Street
# MO    Fisherborough      244 Tracy View             C+       F       D-
# SD    Port Curtisville   446 Cynthia Inlet          C-       B        B
# WV    Jimenezview        432 John Common             A      A+        F
# AK    Stevenshire        238 Andrew Rue             D-       A       A-
# ND    New Joshuaport     877 Walter Neck            D+      C-        B
# ...                                                ...     ...      ...
# MI    North Matthew      055 Clayton Isle           B-       C        B
# MT    Chadton            601 Richards Road          A-       D       D+
# SC    Diazmouth          385 Robin Harbors           F       D       B-
# VA    Laurentown         255 Gonzalez Land          C+      B-        F
# NE    South Kennethmouth 346 Wallace Pass           C-      B-        A
#
# Category
# Subcategory                                Schools
# State City               Street
# MO    Fisherborough      244 Tracy View         A+
# SD    Port Curtisville   446 Cynthia Inlet      D+
# WV    Jimenezview        432 John Common         B
# AK    Stevenshire        238 Andrew Rue         A-
# ND    New Joshuaport     877 Walter Neck         B
# ...                                            ...
# MI    North Matthew      055 Clayton Isle       C+
# MT    Chadton            601 Richards Road       D
# SC    Diazmouth          385 Robin Harbors      D+
# VA    Laurentown         255 Gonzalez Land      D-
# NE    South Kennethmouth 346 Wallace Pass       A-
#
# [251 rows x 4 columns]

# %%
neighborhoods.index.get_level_values(0)
# Out:
# Index(['MO', 'SD', 'WV', 'AK', 'ND', 'ID', 'TN', 'DC', 'OH', 'ND',
#        ...
#        'AK', 'IA', 'ME', 'KS', 'WA', 'MI', 'MT', 'SC', 'VA', 'NE'],
#       dtype='object', name='State', length=251)

# %%
neighborhoods.index.get_level_values("State")
# Out:
# Index(['MO', 'SD', 'WV', 'AK', 'ND', 'ID', 'TN', 'DC', 'OH', 'ND',
#        ...
#        'AK', 'IA', 'ME', 'KS', 'WA', 'MI', 'MT', 'SC', 'VA', 'NE'],
#       dtype='object', name='State', length=251)

# %%
neighborhoods.index.get_level_values(1)
neighborhoods.index.get_level_values("City")
# Out:
# Index(['Fisherborough', 'Port Curtisville', 'Jimenezview', 'Stevenshire',
#        'New Joshuaport', 'Wellsville', 'Jodiburgh', 'Lake Christopher',
#        'Port Mike', 'Hardyburgh',
#        ...
#        'Scottstad', 'Port Willieport', 'Port Linda', 'Kaylamouth',
#        'Port Shawnfort', 'North Matthew', 'Chadton', 'Diazmouth', 'Laurentown',
#        'South Kennethmouth'],
#       dtype='object', name='City', length=251)

# %%
neighborhoods.index.get_level_values("Street")
neighborhoods.index.get_level_values(2)
# Out:
# Index(['244 Tracy View', '446 Cynthia Inlet', '432 John Common',
#        '238 Andrew Rue', '877 Walter Neck', '696 Weber Stravenue',
#        '285 Justin Corners', '607 Montoya Harbors', '041 Michael Neck',
#        '550 Gilmore Mountains',
#        ...
#        '114 Jones Garden', '320 Jennifer Mission', '692 Hill Glens',
#        '483 Freeman Via', '691 Winters Bridge', '055 Clayton Isle',
#        '601 Richards Road', '385 Robin Harbors', '255 Gonzalez Land',
#        '346 Wallace Pass'],
#       dtype='object', name='Street', length=251)

# %%
# refer the columns

neighborhoods.columns.names
# Out:
# FrozenList(['Category', 'Subcategory'])

# %%
neighborhoods.columns.get_level_values(0)                           
neighborhoods.columns.get_level_values("Category")                  # both results the same
# Out:
# Index(['Culture', 'Culture', 'Services', 'Services'], dtype='object', name='Category')

# %%
neighborhoods.columns.get_level_values(1)                           
neighborhoods.columns.get_level_values("Subcategory")               # both results the same
# Out:
# Index(['Restaurants', 'Museums', 'Police', 'Schools'], dtype='object', name='Subcategory')

# %%
neighborhoods.sort_index(ascending=False)
# Out:
# Category                                      Culture         Services
# Subcategory                               Restaurants Museums   Police Schools
# State City           Street
# WY    Reneeshire     717 Patel Square               B      B+        D       A
#       Port Jason     624 Faulkner Orchard          A-       F       C+      C+
#       Martintown     013 Bell Mills                C-       D       A-      B-
#       Lake Nicole    933 Jennifer Burg              C      A+       A-       C
#                      754 Weaver Turnpike            B      D-        B       D
# ...                                               ...     ...      ...     ...
# AL    Clarkland      430 Douglas Mission            A       F       C+      B+
# AK    Stevenshire    238 Andrew Rue                D-       A       A-      A-
#       Scottstad      114 Jones Garden              D-      D-        D       D
#                      082 Leblanc Freeway            D      C-        D      B+
#       Rowlandchester 386 Rebecca Cove              C-      A-       A+       C
#
# [251 rows x 4 columns]

# %%
neighborhoods.sort_index(ascending=[True, False, True])
# Out:
# Category                                      Culture         Services
# Subcategory                               Restaurants Museums   Police Schools
# State City           Street
# AK    Stevenshire    238 Andrew Rue                D-       A       A-      A-
#       Scottstad      082 Leblanc Freeway            D      C-        D      B+
#                      114 Jones Garden              D-      D-        D       D
#       Rowlandchester 386 Rebecca Cove              C-      A-       A+       C
# AL    Vegaside       191 Mindy Meadows             B+      A-       A+      D+
# ...                                               ...     ...      ...     ...
# WY    Port Jason     624 Faulkner Orchard          A-       F       C+      C+
#       Martintown     013 Bell Mills                C-       D       A-      B-
#       Lake Nicole    754 Weaver Turnpike            B      D-        B       D
#                      933 Jennifer Burg              C      A+       A-       C
#       Hardyburgh     227 Andrew Parkway             D      C-       D-       C
#
# [251 rows x 4 columns]

# %%
neighborhoods.sort_index(level=1, ascending=True)               # sorting according to the 1st index column, which is City
# Out:
# Category                                      Culture         Services
# Subcategory                               Restaurants Museums   Police Schools
# State City          Street
# AR    Allisonland   124 Diaz Brooks                C-      A+        F      C+
# GA    Amyburgh      941 Brian Expressway            B       B       D-      C+
# IA    Amyburgh      163 Heather Neck                F       D       A+      A-
# ID    Andrewshire   952 Ellis Drive                C+      A-       C+       A
# UT    Baileyfort    919 Stewart Hills              D+      C+        A       C
# ...                                               ...     ...      ...     ...
# NC    West Scott    348 Jack Branch                A-      D-       A-       A
# SD    West Scott    139 Hardy Vista                C+      A-       D+      B-
# IN    Wilsonborough 066 Carr Road                  A+      C-        B       F
# NC    Wilsonshire   871 Christopher Vista          B+       B       D+       F
# NV    Wilsonshire   542 Jessica Stream              A      A+       C-      C+
#
# [251 rows x 4 columns]

# %%
neighborhoods.sort_index(level=[1, 2], ascending=[True, False])       

neighborhoods.sort_index(level=["City", "Street"], ascending=[True, False])             # Both Same
# Out:
# Category                                      Culture         Services
# Subcategory                               Restaurants Museums   Police Schools
# State City          Street
# AR    Allisonland   124 Diaz Brooks                C-      A+        F      C+
# GA    Amyburgh      941 Brian Expressway            B       B       D-      C+
# IA    Amyburgh      163 Heather Neck                F       D       A+      A-
# ID    Andrewshire   952 Ellis Drive                C+      A-       C+       A
# UT    Baileyfort    919 Stewart Hills              D+      C+        A       C
# ...                                               ...     ...      ...     ...
# NC    West Scott    348 Jack Branch                A-      D-       A-       A
# SD    West Scott    139 Hardy Vista                C+      A-       D+      B-
# IN    Wilsonborough 066 Carr Road                  A+      C-        B       F
# NC    Wilsonshire   871 Christopher Vista          B+       B       D+       F
# NV    Wilsonshire   542 Jessica Stream              A      A+       C-      C+
#
# [251 rows x 4 columns]

# %%
neighborhoods.sort_index(
    axis=1,
    level="Category",
    ascending=True
)                                                   # Category: Services and Culture were in ascending order

# we have two axis. axis=0 is for row and axis=1 is for column
# Out:
# Category                                   Culture             Services  \
# Subcategory                                Museums Restaurants   Police
# State City               Street
# MO    Fisherborough      244 Tracy View          F          C+       D-
# SD    Port Curtisville   446 Cynthia Inlet       B          C-        B
# WV    Jimenezview        432 John Common        A+           A        F
# AK    Stevenshire        238 Andrew Rue          A          D-       A-
# ND    New Joshuaport     877 Walter Neck        C-          D+        B
# ...                                            ...         ...      ...
# MI    North Matthew      055 Clayton Isle        C          B-        B
# MT    Chadton            601 Richards Road       D          A-       D+
# SC    Diazmouth          385 Robin Harbors       D           F       B-
# VA    Laurentown         255 Gonzalez Land      B-          C+        F
# NE    South Kennethmouth 346 Wallace Pass       B-          C-        A
#
# Category
# Subcategory                                Schools
# State City               Street
# MO    Fisherborough      244 Tracy View         A+
# SD    Port Curtisville   446 Cynthia Inlet      D+
# WV    Jimenezview        432 John Common         B
# AK    Stevenshire        238 Andrew Rue         A-
# ND    New Joshuaport     877 Walter Neck         B
# ...                                            ...
# MI    North Matthew      055 Clayton Isle       C+
# MT    Chadton            601 Richards Road       D
# SC    Diazmouth          385 Robin Harbors      D+
# VA    Laurentown         255 Gonzalez Land      D-
# NE    South Kennethmouth 346 Wallace Pass       A-
#
# [251 rows x 4 columns]

# %%
neighborhoods.sort_index(
    axis=1,
    level="Subcategory",
    ascending=True
)                                                   # Subcategory items are sorted.
# Out:
# Category                                   Culture Services     Culture  \
# Subcategory                                Museums   Police Restaurants
# State City               Street
# MO    Fisherborough      244 Tracy View          F       D-          C+
# SD    Port Curtisville   446 Cynthia Inlet       B        B          C-
# WV    Jimenezview        432 John Common        A+        F           A
# AK    Stevenshire        238 Andrew Rue          A       A-          D-
# ND    New Joshuaport     877 Walter Neck        C-        B          D+
# ...                                            ...      ...         ...
# MI    North Matthew      055 Clayton Isle        C        B          B-
# MT    Chadton            601 Richards Road       D       D+          A-
# SC    Diazmouth          385 Robin Harbors       D       B-           F
# VA    Laurentown         255 Gonzalez Land      B-        F          C+
# NE    South Kennethmouth 346 Wallace Pass       B-        A          C-
#
# Category                                   Services
# Subcategory                                 Schools
# State City               Street
# MO    Fisherborough      244 Tracy View          A+
# SD    Port Curtisville   446 Cynthia Inlet       D+
# WV    Jimenezview        432 John Common          B
# AK    Stevenshire        238 Andrew Rue          A-
# ND    New Joshuaport     877 Walter Neck          B
# ...                                             ...
# MI    North Matthew      055 Clayton Isle        C+
# MT    Chadton            601 Richards Road        D
# SC    Diazmouth          385 Robin Harbors       D+
# VA    Laurentown         255 Gonzalez Land       D-
# NE    South Kennethmouth 346 Wallace Pass        A-
#
# [251 rows x 4 columns]

# %% [markdown]
# ### **Extracting Columns or rows**

# %%
neighborhoods.loc["TX"]
# Out:
# Category                         Culture         Services
# Subcategory                  Restaurants Museums   Police Schools
# City        Street
# Leeberg     693 Avila Pines           C+       F       A+      D+
# Jacksonfort 332 Rachel Way            D+      A-       C-       D
# Kingchester 534 Gordon Falls           C      D+        B       B

# %%
neighborhoods.loc["GA"]
# Out:
# Category                                Culture         Services
# Subcategory                         Restaurants Museums   Police Schools
# City           Street
# Tinaborough    946 Lindsay Port               B       C        D       F
# New Carmenland 943 James Lake                B+      B-       C+      C-
# Amyburgh       941 Brian Expressway           B       B       D-      C+
# Trevorville    283 Kelli Forest               D       C       D-      C+
# Spencechester  570 Davis Isle                 F      C-       D-      C-

# %%
neighborhoods.loc[("MT", "Chadton", "601 Richards Road")]
# Out:
# Category  Subcategory
# Culture   Restaurants    A-
#           Museums         D
# Services  Police         D+
#           Schools         D
# Name: (MT, Chadton, 601 Richards Road), dtype: object

# %%
neighborhoods.loc[("SC", "Diazmouth")]
# Out:
# C:\Users\toapr\AppData\Local\Temp\ipykernel_23944\3172131420.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   neighborhoods.loc[("SC", "Diazmouth")]
# Category              Culture         Services
# Subcategory       Restaurants Museums   Police Schools
# Street
# 385 Robin Harbors           F       D       B-      D+

# %%
neighborhoods.loc[:,"Services"]
# Out:
# Subcategory                                Police Schools
# State City               Street
# MO    Fisherborough      244 Tracy View        D-      A+
# SD    Port Curtisville   446 Cynthia Inlet      B      D+
# WV    Jimenezview        432 John Common        F       B
# AK    Stevenshire        238 Andrew Rue        A-      A-
# ND    New Joshuaport     877 Walter Neck        B       B
# ...                                           ...     ...
# MI    North Matthew      055 Clayton Isle       B      C+
# MT    Chadton            601 Richards Road     D+       D
# SC    Diazmouth          385 Robin Harbors     B-      D+
# VA    Laurentown         255 Gonzalez Land      F      D-
# NE    South Kennethmouth 346 Wallace Pass       A      A-
#
# [251 rows x 2 columns]

# %%
neighborhoods.loc[:, ("Services", "Schools")]
# Out:
# State  City                Street
# MO     Fisherborough       244 Tracy View       A+
# SD     Port Curtisville    446 Cynthia Inlet    D+
# WV     Jimenezview         432 John Common       B
# AK     Stevenshire         238 Andrew Rue       A-
# ND     New Joshuaport      877 Walter Neck       B
#                                                 ..
# MI     North Matthew       055 Clayton Isle     C+
# MT     Chadton             601 Richards Road     D
# SC     Diazmouth           385 Robin Harbors    D+
# VA     Laurentown          255 Gonzalez Land    D-
# NE     South Kennethmouth  346 Wallace Pass     A-
# Name: (Services, Schools), Length: 251, dtype: object

# %%
neighborhoods.loc["NE", ("Services", "Schools")]
# Out:
# City                Street
# South Nathan        821 Jake Fork        A
# Shawnchester        802 Cook Cliff       A
# Barryborough        460 Anna Tunnel      A
# South Kennethmouth  346 Wallace Pass    A-
# Name: (Services, Schools), dtype: object

# %%
# neighborhoods["NE":"NH", ("Services", "Schools")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: slice('NE', 'NH', None)
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 neighborhoods["NE":"NH", ("Services", "Schools")]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4091, in DataFrame.__getitem__(self, key)
#    4084     if not is_mi and (
#    4085         self.columns.is_unique
#    4086         and key in self.columns
#    4087         or key in self.columns.drop_duplicates(keep=False)
#    4088     ):
#    4089         return self._get_item_cache(key)
# -> 4091     elif is_mi and self.columns.is_unique and key in self.columns:
#    4092         return self._getitem_multilevel(key)
#    4094 # Do we have a slicer (on rows)?
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\multi.py:1343, in MultiIndex.__contains__(self, key)
#    1341 hash(key)
#    1342 try:
# -> 1343     self.get_loc(key)
#    1344     return True
#    1345 except (LookupError, TypeError, ValueError):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\multi.py:3072, in MultiIndex.get_loc(self, key)
#    3068 if keylen == self.nlevels and self.is_unique:
#    3069     # TODO: what if we have an IntervalIndex level?
#    3070     #  i.e. do we need _index_as_unique on that level?
#    3071     try:
# -> 3072         return self._engine.get_loc(key)
#    3073     except KeyError as err:
#    3074         raise KeyError(key) from err
#
# File pandas/_libs/index.pyx:786, in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3818, in Index.get_loc(self, key)
#    3813 except KeyError as err:
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
# -> 3818         raise InvalidIndexError(key)
#    3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#
# InvalidIndexError: slice('NE', 'NH', None)
